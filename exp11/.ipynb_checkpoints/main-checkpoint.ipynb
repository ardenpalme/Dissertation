# %% [markdown]
# # Convergence per Attack per Algorithm

# %%
# %load_ext autoreload
import sys
import os
import json
import time
import numpy as np
import matplotlib.pyplot as plt
from datetime import timedelta
import pandas as pd
import seaborn as sns
from pathlib import Path
from fastnanoid import generate
from datetime import datetime

# %%
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))
lib_path = project_root / "lib"
sys.path.insert(0, str(lib_path))        
sys.path.insert(0, str(project_root))

# %%
# %autoreload 2
from lib.graph_factory import GraphFactory, add_graph_plot
from lib.proj_const_estimator import ProjConstEstimator
from lib.utils import fetch_dataset, get_alphas, rng, seed
from lib.classifier import ByzClassifier
from lib.system import SystemSimulator
from lib.config import BASE_CONF, NUM_NODES

# %%
# Helper Functions
fmt = lambda sec : f"{sec // 60}m {sec % 60:.2f}s"

# %%
RUN_DIR = os.path.join(Path().resolve(),'runs')
config = BASE_CONF
b = 9 # config['train']['b']
config['graph_args'] = {
    'ws_k': 6,
    'ws_p': 0.1,
    'rand_reg_deg':b+1,
    'geom_radius':0.4,
    'er_p':min(1.0, 3.0 * np.log(NUM_NODES) / NUM_NODES),
}
config['graph_weights'] = 'MH'
graphs = ['random-regular','watts-strogatz', 'geometric']
ATKS = ['label_flip', 'sign_flip', 'gaussian', 'ALIE', 'IPM']
# ALGS = ['RDSGD', 'ORACLE', 'IOS', 'SCC', 'TriMean', 'CooMed']
ALGS = ['RDSGD', 'ORACLE']
COLORS = dict(zip(ALGS, ['C0', 'C1', 'C2', 'C3', 'C4']))
local_seed = 777
clf_optimal_op_pt = {
    'random-regular' : dict(cost_fp=6.0, cost_fn=1.0),
}
# for random-regular graph, for all attacks the clf_optimal_op_pt have params dict(cost_fp=6.0, cost_fn=1.0) producing optimal tau_C's

# %%
global_dataset = fetch_dataset('MNIST')
gf = GraphFactory(config['train']['num_nodes'], b)
proj_const_estimator = ProjConstEstimator(config, global_dataset, gf) 
clf = ByzClassifier(config, global_dataset, gf)
sys_sim = SystemSimulator(config, global_dataset, gf)

# %%
# Fix a graph topology and attack
config['graph_type']='erdos-renyi'
atk = 'sign_flip'
RUN_ID=9

# %%
proj_const_estimator.configure(config, seed('proj-const-estimator'))
proj_const = proj_const_estimator.estimate()

# %%
# %%time
clf_sim_data = clf.run_simulations(config, proj_const, seed('clf','simulation-seed'))
# Out:
# Simulating RDSGD @ (beta_C=0.1, gamma_C=0.12)
# Building training set. Simulating ['label_flip', 'sign_flip', 'gaussian', 'ALIE', 'IPM'] (seed 70998088522)
# Building validation set I. Simulating ['label_flip', 'sign_flip', 'gaussian', 'ALIE', 'IPM'] (seed 45939939618)
# Building validation set II. Simulating ['label_flip', 'sign_flip', 'gaussian', 'ALIE', 'IPM'] (seed 2576812976736)
# Building test set. Simulating ['label_flip', 'sign_flip', 'gaussian', 'ALIE', 'IPM'] (seed 906269717930)
# CPU times: user 54min 34s, sys: 1min 16s, total: 55min 50s
# Wall time: 4min 59s

# %%
# %%time
clf_est, clf_preproc = clf.fit()
# Out:
# CPU times: user 41.9 s, sys: 164 ms, total: 42.1 s
# Wall time: 26 s

# %%
clf_op_pt = clf.calc_optimal_op_pt(cost_fp=6.0, cost_fn=1.0)
clf_metrics = clf.test()

# %%
prelim_metrics = dict()
prelim_metrics['proj_const'] = proj_const
prelim_metrics.update(clf_op_pt)
prelim_metrics.update(clf_metrics)
display(pd.DataFrame([prelim_metrics]))
# Out:
#    proj_const    C_fpr     C_fnr     C_tau     cv_ap  \
# 0    2.054466  0.03265  0.154238  0.869102  0.980282
#
#                                            cv_params  prevalence       tau  \
# 0  {'lr__C': 10.0, 'rbf__gamma': 0.02, 'rbf__n_co...    0.542857  0.869102
#
#       tn    fp    fn     tp    beta_C   gamma_C   roc_auc  avg_prec
# 0  22379  1621  4368  24132  0.153263  0.067542  0.947446  0.937726

# %%
fig_clf, ax_clf = plt.subplots(1,1,figsize=(6,4))
clf.plot_pr(ax_clf)
plt.show()

# %%
# %%time
sim_params = {
    'algorithms': ALGS,
    'atk_type': atk,
    'threat_model': 'T3',
    'seed': local_seed
}
params_C = dict()

# Specifies RDSGD_ORACLE Parameters
params_C['C_fpr'] = clf_metrics['gamma_C']
params_C['C_fnr'] = clf_metrics['beta_C']

# Specifies RDSGD Parameters
params_C['C_tau'] = clf_op_pt['C_tau']

sys_sim.init_simulation(config, proj_const, clf_preproc, clf_est, params_C, seed(atk, local_seed))
df = sys_sim.simulate(sim_params)
# Out:
# =========================RDSGD==========================
# [k=50] train_loss: [0.952,1.634],test_acc: [0.699,0.817]
# [k=100] train_loss: [1.145,1.753],test_acc: [0.777,0.851]
# [k=150] train_loss: [1.230,1.811],test_acc: [0.780,0.825]
# =========================ORACLE=========================
# [k=50] train_loss: [1.134,1.659],test_acc: [0.767,0.830]
# [k=100] train_loss: [1.180,1.672],test_acc: [0.807,0.840]
# [k=150] train_loss: [1.203,1.678],test_acc: [0.811,0.845]
# CPU times: user 18min 45s, sys: 6.25 s, total: 18min 51s
# Wall time: 56.6 s

# %%
df.to_csv(f'{config['graph_type']}_{atk}_results_dataset_{RUN_ID}.csv')

# %%
fig, ax = plt.subplots(1,2,figsize=(10,4))
for idx, alg in enumerate(['RDSGD', 'ORACLE']):
    sns.lineplot(df.loc[alg], x='k', y='gamma_k', ax=ax[0], label=f'{alg}_FPR')
    sns.lineplot(df.loc[alg], x='k', y='beta_k', ax=ax[0], label=f'{alg}_FNR')
    sns.lineplot(df.loc[alg], x='k', y='byz_w_k', ax=ax[1], label=f'{alg}')
ax[0].set(title=f'Realized Operating Point ({atk})', xlabel='Iteration (k)', ylabel='')
ax[1].set(title=f'Admitted Byzantine Mass ({atk})', xlabel='Iteration (k)', ylabel='')
ax[0].legend()
ax[1].legend()
plt.show()
fig.savefig(f'{config['graph_type']}_{atk}_roc_pt_{RUN_ID}.png')

# %%
fig, ax = plt.subplots(1,1,figsize=(6,4))
sns.lineplot(data=df, x='k',y='C_unif', hue='alg', ax=ax)
ax.legend()
ax.set(
    title=f'Consensus Contraction (T3 {atk})',
    yscale='log',  
    xlabel='Iteration (k)', ylabel='Contraction (C_k)')
plt.show()
fig.savefig(f'{config['graph_type']}_{atk}_contraction_{RUN_ID}.png')

# %%
fig,ax = plt.subplots(1,1,figsize=(6,4))
ranges = [(df.loc[alg,'max_test_acc'].mean()-df.loc[alg,'min_test_acc'].mean())*100 for alg in ALGS]
ax.bar(ALGS,ranges)
ax.set(title=f'Maximum Test Accuracy Gap ({atk})',ylabel='Percentage (%)')
plt.xticks(rotation=45, ha='right')
plt.show()
fig.savefig(f'{config['graph_type']}_{atk}_max_test_acc_gap_1.png')

# %%
df2 = pd.DataFrame()
# min across nodes of test accuracy at final iteration
df2['lb_node_ta'] = df['min_test_acc'].groupby(['alg']).nth(-1).groupby(['alg']).first() 

# max across nodes of test accuracy at final iteration 
df2['ub_node_ta'] = df['max_test_acc'].groupby(['alg']).nth(-1).groupby(['alg']).first() 

# mean test accuracy taken over system
ser = df['test_acc'].groupby(['alg']).agg('mean')
ser['RDSGD'] = df.loc['RDSGD','test_acc_pi'].mean()
ser['ORACLE'] = df.loc['ORACLE','test_acc_pi'].mean()
df2['sys_mta'] = ser

# %%
display(df2)
df2.to_csv(f'{config['graph_type']}_{atk}_lb-ub-ta_data.csv')
# Out:
#         lb_node_ta  ub_node_ta   sys_mta
# alg
# ORACLE    0.810823    0.847143  0.836907
# RDSGD     0.780952    0.835281  0.797250

# %%
# Sort by something if you like (e.g., by lb)
df2 = df2.sort_values('lb_node_ta')

# Plot
fig, ax = plt.subplots(figsize=(8, 6))

# Horizontal bars: each from lb to ub
# Use barh with left=lb and width=(ub-lb)
y_pos = np.arange(len(df2))
bar_widths = df2['ub_node_ta'] - df2['lb_node_ta']
ax.barh(y_pos, width=bar_widths, left=df2['lb_node_ta'],
        height=0.5, color='skyblue', edgecolor='navy', alpha=0.7,
        label='LB-UB Range')

# Mark sys_mta with a point (e.g., diamond)
ax.scatter(df2['sys_mta'], y_pos, color='red', marker='D', s=80,
           label='asymptotic TA', zorder=5)

# Add a vertical reference line (e.g., the overall mean of sys_mta)
ref_line = df2['sys_mta'].mean()   # or any fixed value like 0.78
ax.axvline(x=ref_line, color='gray', linestyle='--', linewidth=1.5,
           label=f'Mean TA = {ref_line:.3f}')

# Set y-ticks to algorithm names
ax.set_yticks(y_pos)
ax.set_yticklabels(df2.index)
ax.set_xlabel('Test Accuracy')
ax.set_xlabel('Value')
ax.set_title(f'Inter-node TA Range and Asymptotic TA (T3:{atk})')
ax.legend()
ax.grid(axis='x', alpha=0.3)
fig.savefig(f'{config['graph_type']}_{atk}_inter_node_TA.png')
plt.tight_layout()
plt.show()
