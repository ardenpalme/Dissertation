# %%
# %load_ext autoreload
import sys
from pathlib import Path
import networkx as nx
import numpy as np
import seaborn as sns
from scipy.linalg import eigh
import matplotlib.pyplot as plt
import scipy.linalg as sla
import pandas as pd
import copy

# %%
project_root = Path().resolve()
sys.path.insert(0, str(project_root))
lib_path = project_root / "lib"
sys.path.insert(0, str(lib_path))        
sys.path.insert(0, str(project_root))

# %%
# %autoreload 2    
from lib.graph_factory import GraphFactory, add_graph_plot, calc_graph_metrics
from lib.utils import rng, seed
from lib.config import BASE_CONF, GLOBAL_SEED, NUM_NODES
from lib.metrics import effective_mixing, MetricsCalculator
from lib.utils import fetch_dataset, dirichlet_partition

# %%
def calc_constants(W, H, B, gamma_vec, pi_t, beta_C=0.1):
    Wb, pi, lam = effective_mixing(W, H, gamma_vec, pi_t)
    dp = dirichlet_partition(global_dataset['y_train'], NUM_NODES, config['data_heterogeneity'], rng('dir', 'data', 'graphs'))
    dB_max = max(W[i, B].sum() for i in H) if len(B) else 0.0

    alphas = 0.5
    mu = 1
    r_ub = np.clip((((alphas * mu) / (4*dB_max))-beta_C)/(1-beta_C), 0, 1)
    
    return dict(dB_max=dB_max, r_ub=r_ub)

# %%
def get_graph_args(num_byz_nodes, tar_dir_het_param):
    target_pi = rng('dir','graphs').dirichlet(np.full(NUM_NODES, tar_dir_het_param))
    grap_args = {
        'ba_m': 5,
        'ws_k': 6,
        'ws_p': 0.1,
        'rand_reg_deg':10,
        'geom_radius':0.23,
        'er_p':min(1.0, 3.0 * np.log(NUM_NODES) / NUM_NODES),
        'MH_target_pi':target_pi,
    }
    if(num_byz_nodes == 5):
        r_ub = {
            'erdos-renyi': 0.1461,
            'random-regular': 0.1195,
            'watts-strogatz': 0.0711,
            'geometric': 0.0625,
            'complete': 0.3438
        }
        return grap_args, r_ub
        
    elif(num_byz_nodes < 9 and num_byz_nodes > 5):
        grap_args['geometric'] = 0.6
        
        r_ub = {
            'erdos-renyi': 0.043,
            'random-regular': 0.0,
            'watts-strogatz': 0.0,
            'geometric': 0.0,
            'complete': 0.0799
        }
        return grap_args, r_ub
    else: raise ValueError(f'No graph parameters for b={num_byz_nodes}')

config = copy.deepcopy(BASE_CONF)
b = 8
h = NUM_NODES-b
graphs = ['erdos-renyi', 'random-regular','watts-strogatz', 'geometric', 'barabasi-albert']
local_seed = 333
gamma = np.clip((0.03*np.linspace(-1,1,NUM_NODES)) + 0.2, 0, 0.95)
pi_t = (1 - gamma) * np.full(NUM_NODES, 1.0/NUM_NODES)

# %%
global_dataset = fetch_dataset('MNIST')
mc = MetricsCalculator(config, global_dataset, rng('mc','exp11'))
gf = GraphFactory(NUM_NODES, b)

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
sns.barplot(x=np.arange(NUM_NODES), y=np.sort(pi_t)[::-1], ax=ax)
ax.axhline(1/NUM_NODES, ls="--", color="crimson")
ax.set_title("Stationary Weight Distribution")
plt.close()

# %%
fig, ax = plt.subplots(1,5, figsize=(14,2))
df = pd.DataFrame()
for i, g in enumerate(graphs):
    metrics = {'graph_type':g}
    G,W,B,H = gf.create_graph(g, "MH_gen", local_seed, **get_graph_args(b,1)[0])
    metrics.update(calc_constants(W, H, B, gamma, pi_t, beta_C=0.2))
    metrics.update(calc_graph_metrics(W,H,gamma,pi_t))
    df[g]= metrics
    add_graph_plot(G,B,ax[i])
    ax[i].set_title(g)
df = df.T
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 6
#       4 metrics = {'graph_type':g}
#       5 G,W,B,H = gf.create_graph(g, "MH_gen", local_seed, **get_graph_args(b,1)[0])
# ----> 6 metrics.update(calc_constants(W, H, B, gamma, pi_t, beta_C=0.2))
#       7 metrics.update(calc_graph_metrics(W,H,gamma,pi_t))
#       8 df[g]= metrics
#
# Cell In[4], line 2, in calc_constants(W, H, B, gamma_vec, pi_t, beta_C)
#       1 def calc_constants(W, H, B, gamma_vec, pi_t, beta_C=0.1):
# ----> 2     Wb, pi, lam = effective_mixing(W, H, gamma_vec, pi_t)
#       3     dp = dirichlet_partition(global_dataset['y_train'], NUM_NODES, config['data_heterogeneity'], rng('dir', 'data', 'graphs'))
#       4     dB_max = max(W[i, B].sum() for i in H) if len(B) else 0.0
#
# File ~/Documents/UoE/Dissertation/numerics/lib/metrics.py:42, in effective_mixing(W, H, gamma_vec, pi_t)
#      39 assert abs(ev[j] - 1.0) < 1e-8, "honest subgraph disconnected"
#      40 pi_num = np.real(evec[:, j]); pi_num /= pi_num.sum()
# ---> 42 assert np.allclose(pi, pi_num, rtol=1e-8), np.abs(pi - pi_num).max()
#      43 assert np.allclose(pi[:, None] * Wbar, (pi[:, None] * Wbar).T, atol=1e-10)
#      45 sp = np.sqrt(pi)
#
# AssertionError: 0.2045736523276967

# %%
df

# %%
df['r_ub'] = df['r_ub'].apply(lambda arr: np.round(arr, 4))
df['r_ub'].to_dict()
