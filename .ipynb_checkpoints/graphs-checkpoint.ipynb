# %%
# %reload_ext autoreload
# %autoreload 2
from graph_factory import GraphFactory, add_graph_plot, calc_graph_metrics
import networkx as nx
import numpy as np
import cvxpy as cp
from scipy.linalg import eigh
import matplotlib.pyplot as plt
import scipy.linalg as sla

# %%
global_seed = 0
global_rng = np.random.default_rng(global_seed)

# %% [markdown]
# ## Graph Examples

# %%
# Parameters
num_nodes = 20
b = 3

# %%
# %%capture
gf = GraphFactory(num_nodes, b, global_seed)
fig, ax = plt.subplots(1,4,figsize=(12,3))

# %%
# %%capture
graph_args = {
    'barbell_m1': (num_nodes-2) // 2, 
    'barbell_m2': 2,
}
G,W,sampling_subset = gf.create_graph("barbell", "MH", **graph_args)
B = global_rng.choice(sampling_subset, size=b, replace=False)
H = np.array(list(set(np.arange(num_nodes)) - set(B)))

add_graph_plot(G,B,ax[0])
ax[0].set_title("Barbell")

# %%
# %%capture
graph_args = {'ba_m': 4}
G, W, sampling_subset = gf.create_graph("barabasi-albert", "MH", **graph_args)
B = global_rng.choice(sampling_subset, size=b, replace=False)
H = np.array(list(set(np.arange(num_nodes)) - set(B)))

add_graph_plot(G,B,ax[1])
ax[1].set_title("Barabasi-Albert")

# %%
# %%capture
graph_args = {'er_p': min(1.0, 3.0 * np.log(num_nodes) / num_nodes)}
G, W, sampling_subset = gf.create_graph("erdos-renyi", "MH", **graph_args)
B = global_rng.choice(sampling_subset, size=b, replace=False)
H = np.array(list(set(np.arange(num_nodes)) - set(B)))

add_graph_plot(G,B,ax[2])
ax[2].set_title("Erdos-Renyi")

# %%
# %%capture
graph_args = {'rand_reg_deg': 4}
G, W, sampling_subset = gf.create_graph("random-regular", "MH", **graph_args)
B = global_rng.choice(sampling_subset, size=b, replace=False)
H = np.array(list(set(np.arange(num_nodes)) - set(B)))

add_graph_plot(G,B,ax[3])
ax[3].set_title("Random Regular")

# %%
display(fig)
