# %%
import yaml
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# ## Helpers

# %%
def get_l_perron_vec(arr_str):
    arr_str_clean = arr_str.strip('[]')
    return np.array([float(x) for x in arr_str_clean.split()])

# %%
def purge_runs(df, run_ids, ledger_fname):
    df.drop(index=run_ids, inplace=True)
    for run_id in run_ids:
        fname = f"images/{run_id}.png"
        if os.path.exists(fname):
            os.remove(fname)
        else:
            print(f"File {fname} not found")
    df.to_csv(ledger_fname)

# %% [markdown]
# ## Experiments

# %%
df = pd.read_csv("results.csv", index_col='id')

# %%
graph_cols = ['graph_type', 'graph_weights', 'graph_args']
gen_cols = ['n', 'b', 'K']
T3_perf_cols = ['RDSGD_T3', 'IOS_T3', 'SCC_T3', 'TriMean_T3', 'CooMed_T3']
T0_perf_cols =['RDSGD_T0', 'IOS_T0', 'SCC_T0', 'TriMean_T0', 'CooMed_T0', 'DSGD_T0']

# %% [markdown]
# ### Impact of Graph Topology on Convergence and Generalization

# %% [markdown]
# * sign-flip attack
# * training over all attacks
# * $n=20$, $b=3$ for each topology

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))
sns.barplot(
    data=df.melt(
        id_vars=['graph_type'],
        value_vars=T0_perf_cols,
        var_name='Metric',
        value_name='Test Accuracy'
    ), 
    x='graph_type', 
    y='Test Accuracy', 
    hue='Metric',
    palette='muted6',
    width=0.5,
    ax=ax[0]
)
sns.barplot(
    data=df.melt(
        id_vars=['graph_type'],
        value_vars=T3_perf_cols,
        var_name='Metric',
        value_name='Test Accuracy'
    ),
    x='graph_type', 
    y='Test Accuracy', 
    hue='Metric',
    palette='muted6',
    width=0.5,
    ax=ax[1]
)
ax[0].set_title("Byzantine-Free (T0) Performance")
ax[1].set_title("Byzantine (T3) Performance")
ax[0].set_xlabel("Communication Topology")
ax[1].set_xlabel("Communication Topology")
ax[0].legend(loc='lower right')
ax[1].legend(loc='lower left')

for a in [ax[0], ax[1]]:
    a.tick_params(axis='x', rotation=45)

plt.show()

# %% [markdown]
# ### Impact of Data Heterogeneity on Convergence and Generalization (Erdos-Renyi and Random-Regular)
